# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # **KEY-DATA-STRUCTURE IN PANDAS**
# # *Series*
# # *DataFrame TWO DIMENSTIONAL *

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e']) # creating a series
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df1 = pd.DataFrame({
    'Names': ['Ali', 'Abdullah', 'Ahmed'],
    'Marks': [23, 50, 25]  
})
df1
# Out:
#       Names  Marks
# 0       Ali     23
# 1  Abdullah     50
# 2     Ahmed     25

# %%
df2 = pd.read_csv(r"C:\Users\PC\Desktop\hey.csv")
df2
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df2.head(6) # first 6 rows
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
# 5  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
# 5  Dollars (millions)           H09
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# ...

# %%
df2.tail(6) # last 6 rows
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50979  2013                     Level 3                 ZZ11
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 50979  Food product manufacturing  Percentage           H36
# 50980  Food product manufacturing  Percentage           H37
# 50981  Food product manufacturing  Percentage           H38
# 50982  Food product manufacturing  Percentage           H39
# 50983  Food product manufacturing  Percentage           H40
# 50984  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# ...

# %%
df2.describe() # statistical summary of the data frame
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
df2.info() # information about the data frame including data types and non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         50985 non-null  int64
#  1   Industry_aggregation_NZSIOC  50985 non-null  object
#  2   Industry_code_NZSIOC         50985 non-null  object
#  3   Industry_name_NZSIOC         50985 non-null  object
#  4   Units                        50985 non-null  object
#  5   Variable_code                50985 non-null  object
#  6   Variable_name                50985 non-null  object
#  7   Variable_category            50985 non-null  object
#  8   Value                        50985 non-null  object
#  9   Industry_code_ANZSIC06       50985 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
print(df2.columns) # column names
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %% [markdown]
# # **Data Selection**

# %%
df2["Year"] # Accessing a single column
# Out:
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
#          ...
# 50980    2013
# 50981    2013
# 50982    2013
# 50983    2013
# 50984    2013
# Name: Year, Length: 50985, dtype: int64

# %%
df3=pd.read_csv(r"C:\Users\PC\Desktop\trade.csv") # Reading a CSV file
df3
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0         WTSQ.SFA1CA  1995.03    2368.690       223.0      F  Dollars
# 1         WTSQ.SFA1CA  1995.06    2100.440         NaN      F      NaN
# 2         WTSQ.SFA1CA  1995.09    2070.210        34.0      F  Dollars
# 3         WTSQ.SFA1CA  1995.12    2284.770         NaN      F      NaN
# 4         WTSQ.SFA1CA  1996.03    2134.760      5555.0      F  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 5505      WTSQ.SFZ9CT  2023.12   18772.518         NaN      R  Dollars
# 5506      WTSQ.SFZ9CT  2024.03   18447.589         NaN      R  Dollars
# 5507      WTSQ.SFZ9CT  2024.06   18514.699         NaN      R  Dollars
# 5508      WTSQ.SFZ9CT  2024.09   18452.035         NaN      R  Dollars
# 5509      WTSQ.SFZ9CT  2024.12   18037.314         NaN      F  Dollars
#
#       Magnitude                       Subject  \
# 0             6  Wholesale Trade Survey - WTS
# ...

# %%
df3.rename(columns={'Series_reference':'S_r'},inplace=True) # Renaming a column in the DataFrame  , inplace=True means that the changes are made directly to the original DataFrame without creating a new one.

# %%
df3.info() # Displaying information about the DataFrame after renaming the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5510 entries, 0 to 5509
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S_r             5510 non-null   object
#  1   Period          5510 non-null   float64
#  2   Data_value      5510 non-null   float64
#  3   Suppressed      5 non-null      float64
#  4   STATUS          5510 non-null   object
#  5   UNITS           5508 non-null   object
#  6   Magnitude       5510 non-null   int64
#  7   Subject         5510 non-null   object
#  8   Group           5510 non-null   object
#  9   Series_title_1  5510 non-null   object
#  10  Series_title_2  5510 non-null   object
#  11  Series_title_3  5510 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 516.7+ KB

# %%
df3['Magnitude']=df3['Magnitude'].astype('string') # Changing the data type of a column to 'category' for better memory efficiency and performance

# %%
df3.info() # Displaying information about the DataFrame after changing the data type of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5510 entries, 0 to 5509
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S_r             5510 non-null   object
#  1   Period          5510 non-null   float64
#  2   Data_value      5510 non-null   float64
#  3   Suppressed      5 non-null      float64
#  4   STATUS          5510 non-null   object
#  5   UNITS           5508 non-null   object
#  6   Magnitude       5510 non-null   string
#  7   Subject         5510 non-null   object
#  8   Group           5510 non-null   object
#  9   Series_title_1  5510 non-null   object
#  10  Series_title_2  5510 non-null   object
#  11  Series_title_3  5510 non-null   object
# dtypes: float64(3), object(8), string(1)
# memory usage: 516.7+ KB

# %%
df3['Magnitude'][0]
# Out:
# '6'

# %%
df3[['Period','S_r']] # selecting multiple columns
# Out:
#        Period          S_r
# 0     1995.03  WTSQ.SFA1CA
# 1     1995.06  WTSQ.SFA1CA
# 2     1995.09  WTSQ.SFA1CA
# 3     1995.12  WTSQ.SFA1CA
# 4     1996.03  WTSQ.SFA1CA
# ...       ...          ...
# 5505  2023.12  WTSQ.SFZ9CT
# 5506  2024.03  WTSQ.SFZ9CT
# 5507  2024.06  WTSQ.SFZ9CT
# 5508  2024.09  WTSQ.SFZ9CT
# 5509  2024.12  WTSQ.SFZ9CT
#
# [5510 rows x 2 columns]

# %%
type(df3.iloc[0]) # returns the type of the first row
# Out:
# pandas.core.series.Series

# %%
df3.dropna() # drop rows with any NaN values
# Out:
#            S_r   Period  Data_value  Suppressed STATUS    UNITS Magnitude  \
# 0  WTSQ.SFA1CA  1995.03     2368.69       223.0      F  Dollars         6
# 2  WTSQ.SFA1CA  1995.09     2070.21        34.0      F  Dollars         6
# 4  WTSQ.SFA1CA  1996.03     2134.76      5555.0      F  Dollars         6
# 5  WTSQ.SFA1CA  1996.06     2038.45     42555.0      F  Dollars         6
# 7  WTSQ.SFA1CA  1996.12     2263.97       323.0      F  Dollars         6
#
#                         Subject  \
# 0  Wholesale Trade Survey - WTS
# 2  Wholesale Trade Survey - WTS
# 4  Wholesale Trade Survey - WTS
# 5  Wholesale Trade Survey - WTS
# 7  Wholesale Trade Survey - WTS
#
#                                                Group  \
# 0  Industry by variable - (ANZSIC06) - Subannual ...
# 2  Industry by variable - (ANZSIC06) - Subannual ...
# 4  Industry by variable - (ANZSIC06) - Subannual ...
# 5  Industry by variable - (ANZSIC06) - Subannual ...
# ...

# %%
df3.fillna(0) # fill missing values with 0
# Out:
#               S_r   Period  Data_value  Suppressed STATUS    UNITS Magnitude  \
# 0     WTSQ.SFA1CA  1995.03    2368.690       223.0      F  Dollars         6
# 1     WTSQ.SFA1CA  1995.06    2100.440         0.0      F        0         6
# 2     WTSQ.SFA1CA  1995.09    2070.210        34.0      F  Dollars         6
# 3     WTSQ.SFA1CA  1995.12    2284.770         0.0      F        0         6
# 4     WTSQ.SFA1CA  1996.03    2134.760      5555.0      F  Dollars         6
# ...           ...      ...         ...         ...    ...      ...       ...
# 5505  WTSQ.SFZ9CT  2023.12   18772.518         0.0      R  Dollars         6
# 5506  WTSQ.SFZ9CT  2024.03   18447.589         0.0      R  Dollars         6
# 5507  WTSQ.SFZ9CT  2024.06   18514.699         0.0      R  Dollars         6
# 5508  WTSQ.SFZ9CT  2024.09   18452.035         0.0      R  Dollars         6
# 5509  WTSQ.SFZ9CT  2024.12   18037.314         0.0      F  Dollars         6
#
#                            Subject  \
# ...

# %%
df3['zeros']=[0 for i in range(len(df3)) ]# Adding a new column with all values set to 0
df3
# Out:
#               S_r   Period  Data_value  Suppressed STATUS    UNITS Magnitude  \
# 0     WTSQ.SFA1CA  1995.03    2368.690       223.0      F  Dollars         6
# 1     WTSQ.SFA1CA  1995.06    2100.440         NaN      F      NaN         6
# 2     WTSQ.SFA1CA  1995.09    2070.210        34.0      F  Dollars         6
# 3     WTSQ.SFA1CA  1995.12    2284.770         NaN      F      NaN         6
# 4     WTSQ.SFA1CA  1996.03    2134.760      5555.0      F  Dollars         6
# ...           ...      ...         ...         ...    ...      ...       ...
# 5505  WTSQ.SFZ9CT  2023.12   18772.518         NaN      R  Dollars         6
# 5506  WTSQ.SFZ9CT  2024.03   18447.589         NaN      R  Dollars         6
# 5507  WTSQ.SFZ9CT  2024.06   18514.699         NaN      R  Dollars         6
# 5508  WTSQ.SFZ9CT  2024.09   18452.035         NaN      R  Dollars         6
# 5509  WTSQ.SFZ9CT  2024.12   18037.314         NaN      F  Dollars         6
#
#                            Subject  \
# ...

# %%
df3['+2']=[0 for i in range(len(df3)) ]# Adding a new column with all values set to -2
df3
# Out:
#               S_r   Period  Data_value  Suppressed STATUS    UNITS Magnitude  \
# 0     WTSQ.SFA1CA  1995.03    2368.690       223.0      F  Dollars         6
# 1     WTSQ.SFA1CA  1995.06    2100.440         NaN      F      NaN         6
# 2     WTSQ.SFA1CA  1995.09    2070.210        34.0      F  Dollars         6
# 3     WTSQ.SFA1CA  1995.12    2284.770         NaN      F      NaN         6
# 4     WTSQ.SFA1CA  1996.03    2134.760      5555.0      F  Dollars         6
# ...           ...      ...         ...         ...    ...      ...       ...
# 5505  WTSQ.SFZ9CT  2023.12   18772.518         NaN      R  Dollars         6
# 5506  WTSQ.SFZ9CT  2024.03   18447.589         NaN      R  Dollars         6
# 5507  WTSQ.SFZ9CT  2024.06   18514.699         NaN      R  Dollars         6
# 5508  WTSQ.SFZ9CT  2024.09   18452.035         NaN      R  Dollars         6
# 5509  WTSQ.SFZ9CT  2024.12   18037.314         NaN      F  Dollars         6
#
#                            Subject  \
# ...

# %%
def fx(a):
    return a+2 # Defining a function that adds 2 to the input value
df3['+2']=df3['+2'].apply(fx) # Applying a function to a column in the DataFrame
df3
# Out:
#               S_r   Period  Data_value  Suppressed STATUS    UNITS Magnitude  \
# 0     WTSQ.SFA1CA  1995.03    2368.690       223.0      F  Dollars         6
# 1     WTSQ.SFA1CA  1995.06    2100.440         NaN      F      NaN         6
# 2     WTSQ.SFA1CA  1995.09    2070.210        34.0      F  Dollars         6
# 3     WTSQ.SFA1CA  1995.12    2284.770         NaN      F      NaN         6
# 4     WTSQ.SFA1CA  1996.03    2134.760      5555.0      F  Dollars         6
# ...           ...      ...         ...         ...    ...      ...       ...
# 5505  WTSQ.SFZ9CT  2023.12   18772.518         NaN      R  Dollars         6
# 5506  WTSQ.SFZ9CT  2024.03   18447.589         NaN      R  Dollars         6
# 5507  WTSQ.SFZ9CT  2024.06   18514.699         NaN      R  Dollars         6
# 5508  WTSQ.SFZ9CT  2024.09   18452.035         NaN      R  Dollars         6
# 5509  WTSQ.SFZ9CT  2024.12   18037.314         NaN      F  Dollars         6
#
#                            Subject  \
# ...

# %%
df3.columns # Displaying the column names of the DataFrame
# Out:
# Index(['S_r', 'Period', 'Data_value', 'Suppressed', 'STATUS', 'UNITS',
#        'Magnitude', 'Subject', 'Group', 'Series_title_1', 'Series_title_2',
#        'Series_title_3', 'zeros', '+2'],
#       dtype='object')

# %%
# df3 = df3.drop(columns=['+2'])  # Drop the 'zeros' column

# %%
df3.to_csv(r"C:\Users\PC\Desktop\trade vs code.csv",index=False) # Saving the DataFrame to a CSV file without the index column

# %%
df4=pd.DataFrame({
    'name': ['Ali', 'Abdullah', 'Ahmed'],
    'marks': [23, 50, 25],
    'age': [20, 25, 23]
    
})
df4
# Out:
#        name  marks  age
# 0       Ali     23   20
# 1  Abdullah     50   25
# 2     Ahmed     25   23

# %%
df5=pd.DataFrame({
    'name': ['Ahmad', 'Arjun', 'Ravi', 'Annupama', 'Amit'],
    'marks': [23, 50, 25, 45, 30],
    'age': [20, 25, 23, 30, 28],
})
df5
# Out:
#        name  marks  age
# 0     Ahmad     23   20
# 1     Arjun     50   25
# 2      Ravi     25   23
# 3  Annupama     45   30
# 4      Amit     30   28

# %%
pd.concat([df4,df5]) # Concatenating two DataFrames vertically (row-wise)
# Out:
#        name  marks  age
# 0       Ali     23   20
# 1  Abdullah     50   25
# 2     Ahmed     25   23
# 0     Ahmad     23   20
# 1     Arjun     50   25
# 2      Ravi     25   23
# 3  Annupama     45   30
# 4      Amit     30   28

# %%
d1=pd.DataFrame({
    'name': ['David','Smith', 'John', 'Doe', 'Jane'],
    'marks': [60, 57, 71, 31, 96],
    'age': [30,46,23,12,58],
})
d1
# Out:
#     name  marks  age
# 0  David     60   30
# 1  Smith     57   46
# 2   John     71   23
# 3    Doe     31   12
# 4   Jane     96   58

# %%
d2=pd.DataFrame({
    'name': ['John','Roman','Hillary','Doe','Jane',],
    'Roll No': [5622, 4566, 4596, 1287, 9649],
    
})
d2
# Out:
#       name  Roll No
# 0     John     5622
# 1    Roman     4566
# 2  Hillary     4596
# 3      Doe     1287
# 4     Jane     9649

# %%
pd.merge(d1,d2,on='name')  # Merging same name
# Out:
#    name  marks  age  Roll No
# 0  John     71   23     5622
# 1   Doe     31   12     1287
# 2  Jane     96   58     9649

# %%
df3
# Out:
#               S_r   Period  Data_value  Suppressed STATUS    UNITS Magnitude  \
# 0     WTSQ.SFA1CA  1995.03    2368.690       223.0      F  Dollars         6
# 1     WTSQ.SFA1CA  1995.06    2100.440         NaN      F      NaN         6
# 2     WTSQ.SFA1CA  1995.09    2070.210        34.0      F  Dollars         6
# 3     WTSQ.SFA1CA  1995.12    2284.770         NaN      F      NaN         6
# 4     WTSQ.SFA1CA  1996.03    2134.760      5555.0      F  Dollars         6
# ...           ...      ...         ...         ...    ...      ...       ...
# 5505  WTSQ.SFZ9CT  2023.12   18772.518         NaN      R  Dollars         6
# 5506  WTSQ.SFZ9CT  2024.03   18447.589         NaN      R  Dollars         6
# 5507  WTSQ.SFZ9CT  2024.06   18514.699         NaN      R  Dollars         6
# 5508  WTSQ.SFZ9CT  2024.09   18452.035         NaN      R  Dollars         6
# 5509  WTSQ.SFZ9CT  2024.12   18037.314         NaN      F  Dollars         6
#
#                            Subject  \
# ...

# %% [markdown]
# # *MEAN*

# %%
df3['Period'].mean()
# Out:
# np.float64(2009.601332123412)

# %%
df3['Period'].median() # Median of the 'Period' column
# Out:
# np.float64(2010.03)

# %%
df3['Period'].mode() # Mode of the 'Period' column
# Out:
# 0      1996.03
# 1      1996.06
# 2      1996.09
# 3      1996.12
# 4      1997.03
#         ...
# 111    2023.12
# 112    2024.03
# 113    2024.06
# 114    2024.09
# 115    2024.12
# Name: Period, Length: 116, dtype: float64

# %%
df55=pd.DataFrame([3,1.5,2,5,4.5,3,2,1,0.5  ])

df55.median() # Mean of the DataFrame
# Out:
# 0    2.0
# dtype: float64

# %%
df33=pd.DataFrame([2.5,7,2.5,7,8,2.5,7,8,8])
df33.mode() # Mode of the DataFrame
# Out:
#      0
# 0  2.5
# 1  7.0
# 2  8.0
