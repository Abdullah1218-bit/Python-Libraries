# %% [markdown]
# # **Intermediate Machine Learning**

# %% [markdown]
# # **Simple Linear Regression**

# %%
#libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')
#load data set
df=sns.load_dataset("tips")
# selecting input column 
x=df[['total_bill']]
# selecting output column
y=df[['tip']]
# creating model
model=LinearRegression()
#fitting model
model.fit(x,y)
#predicting model
model.predict([[150]])
# Out:
# array([[16.67394722]])

# %%
sns.lmplot(x='total_bill', y='tip', data=df)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # ***Multiple Linear Regression OR Multilinear Regression***

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')
x=df[['total_bill','size']]
# selecting output column
y=df[['tip']]
# creating model
model=LinearRegression()
#fitting model
model.fit(x,y)
#predicting model
model.predict([[150,3]])
# Out:
# array([[15.15373865]])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')
#import data set
df=sns.load_dataset("tips")
df['smoker']=df['smoker'].map({'Yes':1,'No':0})
df['sex']=df['sex'].map({'Male':1,'Female':0})
df['time']=df['time'].map({'Dinner':1,'Lunch':0})
# selecting input column 
x=df[['total_bill','size','time']]
# selecting output column
y=df[['tip']]
# creating model
model=LinearRegression()
#fitting model
model.fit(x,y)
#predicting model
print(model.predict([[150,3,1]]))
print(model.predict([[150,3,0]]))
# Out:
# [[15.15770326]]
# [[15.16183139]]

# %% [markdown]
# # **Classification**

# %% [markdown]
# # ***Logistic Regression***

# %% [markdown]
# # ***Binary Classification***

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression,LogisticRegression
import warnings
warnings.filterwarnings('ignore')
#import data set
df=sns.load_dataset("tips")

# selecting input column 
x=df[['total_bill','size','tip']]
# selecting output column
y=df[['smoker']]
# creating model
model=LogisticRegression()
#fitting model
model.fit(x,y)

#predict
print(model.predict([[50,1,3]]))
print(model.predict([[50,3,6]]))
# Out:
# ['Yes']
# ['Yes']

# %%
# libraries import
import pandas as pd
import seaborn as sns
from sklearn.naive_bayes import GaussianNB 
warnings.filterwarnings('ignore')
#import data set
df=sns.load_dataset("tips")

# selecting input column 
x=df[['total_bill','size','tip']]
# selecting output column
y=df[['smoker']]
# creating model
model=GaussianNB()
#fitting model
model.fit(x,y)

#predict
print(model.predict([[50,1,3]]))
print(model.predict([[50,3,6]]))
# Out:
# ['Yes']
# ['Yes']

# %% [markdown]
# # ***Descision Trees***

# %%
# libraries import
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.naive_bayes import GaussianNB
#importing descision tree
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
#importing warnings
warnings.filterwarnings('ignore')
#import data set
df=sns.load_dataset("tips")

# selecting input column 
x=df[['total_bill','size']]
# selecting output column
y=df[['tip']]
# creating model
model=DecisionTreeRegressor()
#fitting model
model.fit(x,y)

#predict
print(model.predict([[88,4]]))
print(model.predict([[399,6]]))
# Out:
# [9.]
# [9.]

# %% [markdown]
# # ***Regression Metrics***

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
df=sns.load_dataset('tips')
df.head()
# split train test
x=df[['total_bill','size']]
y=df[['tip']]
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# creating model
model=LinearRegression()
#fitting model
model.fit(x_train,y_train)
#metric to evaluate model
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

y_pred=model.predict(x_test)
# plotting the regression line
print(f'Mean Squared Error:{mean_squared_error(y_test,y_pred)}')
print(f'r2 score:{r2_score(y_test,y_pred)}')
print(f'mean absolute error:{mean_absolute_error(y_test,y_pred)}')

# root mean squared error
print(f'Root mean squared error',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean Squared Error:1.0147607136737133
# r2 score:0.4154081883313667
# mean absolute error:0.7331171898268086
# Root mean squared error 1.0073533211707366
# 195

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
len(x_test),len(y_test),len(y_train),len(x_train)
# Out:
# (49, 49, 195, 195)

# %%
# Out:
# 195

# %%
y_test
# Out:
#       tip
# 163  2.00
# 111  1.00
# 53   1.56
# 82   1.83
# 120  2.31
# ..    ...
# 212  9.00
# 153  2.00
# 198  2.00
# 169  2.00
# 104  4.08
#
# [196 rows x 1 columns]
