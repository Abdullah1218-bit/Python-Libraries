# %% [markdown]
# # ***Customizing Plots in Matplotlib and Seaborn***

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\PC\OneDrive\Desktop\Data\diamonds.csv')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
print(f'number of rows: {df.shape[0]}')
print(f'number of columns: {df.shape[1]}')
print(f'{50*'-'}')
df=df.sample(5000)
print(f'number of rows after sampling : {df.shape[0]}')
print(f'number of columns after sampling : {df.shape[1]}')

df.head()
# Out:
# number of rows: 53940
# number of columns: 10
# --------------------------------------------------
# number of rows after sampling : 5000
# number of columns after sampling : 10
#        carat        cut color clarity  depth  table  price     x     y     z
# 11125   1.00      Ideal     F     SI1   62.4   55.0   4939  6.45  6.37  4.00
# 14683   1.29    Premium     H     SI2   60.1   58.0   5924  7.02  6.95  4.20
# 4288    0.97    Premium     D     SI2   60.4   61.0   3585  6.40  6.37  3.86
# 28762   0.31      Ideal     F     VS1   60.6   56.0    680  4.39  4.42  2.67
# 6226    1.02  Very Good     H     SI2   58.3   61.0   4004  6.57  6.63  3.85

# %%
sns.scatterplot(x='carat',y='price',data=df,hue='color')
plt.legend(title='color', loc='upper right')
plt.title('Scatter plot of carat vs price')
plt.xticks(rotation=45, ha='right',fontsize= 10)
plt.xlabel('carat')
plt.ylabel('price', labelpad=10)
plt.show()

# %%
plt.scatter(x=df['carat'], y=df['price'])
plt.title('Scatter plot of carat vs price')
plt.xlabel('carat')
plt.ylabel('price')

plt.show()
